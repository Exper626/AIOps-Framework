# %%
# !pip install -U langchain-openai -q
# !pip install -U langchain langchain-core langchain-community langchain-openai -q
# !pip install langchain_community tiktoken langchain-openai langchainhub chromadb langchain -q


import os
os.environ['LANGCHAIN_TRACING_V2'] = 'true'
os.environ['LANGCHAIN_ENDPOINT'] = 'https://api.smith.langchain.com'
os.environ['LANGCHAIN_API_KEY'] = ''
os.environ['OPENAI_API_KEY'] = ""


# from dotenv import load_dotenv
# import os

# load_dotenv()
# api_key = os.getenv("API_KEY")
# database_url = os.getenv("DATABASE_URL")


import bs4
from langchain import hub
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI, OpenAIEmbeddings


# Load Documents
loader = WebBaseLoader(
    web_paths=("https://lilianweng.github.io/posts/2023-06-23-agent/",),
    bs_kwargs=dict(
        parse_only=bs4.SoupStrainer(
            class_=("post-content", "post-title", "post-header")
        )
    ),
)
docs = loader.load()

# Split
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
splits = text_splitter.split_documents(docs)

# Embed
vectorstore = Chroma.from_documents(documents=splits, embedding=OpenAIEmbeddings())
retriever = vectorstore.as_retriever()


# Prompt
prompt = hub.pull("rlm/rag-prompt")

# LLM
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

# Post-processing
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# Chain
rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)


rag_chain.invoke("What is Task Decomposition?")

question = "What kinds of pets do I like?"
document = "My favorite pet is a cat."


import tiktoken

def num_tokens_from_string(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

num_tokens_from_string(question, "cl100k_base")


from langchain_openai import OpenAIEmbeddings
embd = OpenAIEmbeddings()
query_result = embd.embed_query(question)
document_result = embd.embed_query(document)
len(query_result)


import numpy as np

def cosine_similarity(vec1, vec2):
    dot_product = np.dot(vec1, vec2)
    norm_vec1 = np.linalg.norm(vec1)
    norm_vec2 = np.linalg.norm(vec2)
    return dot_product / (norm_vec1 * norm_vec2)

similarity = cosine_similarity(query_result, document_result)
print("Cosine Similarity:", similarity)



# Load blog
import bs4
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader(
    web_paths=("https://lilianweng.github.io/posts/2023-06-23-agent/",),
    bs_kwargs=dict(
        parse_only=bs4.SoupStrainer(
            class_=("post-content", "post-title", "post-header")
        )
    ),
)
blog_docs = loader.load()


# Split
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=300,
    chunk_overlap=50)

# Make splits
splits = text_splitter.split_documents(blog_docs)


# Index
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
vectorstore = Chroma.from_documents(documents=splits, embedding=OpenAIEmbeddings())

retriever = vectorstore.as_retriever()


# Index
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
vectorstore = Chroma.from_documents(documents=splits,
                                    embedding=OpenAIEmbeddings())


retriever = vectorstore.as_retriever(search_kwargs={"k": 1})
docs = retriever.get_relevant_documents("What is Task Decomposition?")
len(docs)



from langchain_openai import ChatOpenAI
from langchain.prompts import ChatPromptTemplate

# Prompt
template = """Answer the question based only on the following context:
{context}

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)
prompt

# LLM
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

# Chain
chain = prompt | llm

# Run
chain.invoke({"context":docs,"question":"What is Task Decomposition?"})

from langchain import hub
prompt_hub_rag = hub.pull("rlm/rag-prompt")

prompt_hub_rag


from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

rag_chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

rag_chain.invoke("What is Task Decomposition?")
# Out:
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ashwinir\AppData\Local\Programs\Python\Python312\Lib\site-packages\~ydantic_core'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dspy 2.6.16 requires cachetools>=5.5.0, but you have cachetools 5.3.2 which is incompatible.
# dspy 2.6.16 requires openai<=1.61.0,>=0.28.1, but you have openai 1.76.0 which is incompatible.
# gradio 5.23.1 requires aiofiles<24.0,>=22.0, but you have aiofiles 24.1.0 which is incompatible.
# graphrag 2.1.0 requires json-repair<0.31.0,>=0.30.3, but you have json-repair 0.40.0 which is incompatible.
# graphrag 2.1.0 requires networkx<4.0.0,>=3.4.2, but you have networkx 3.1 which is incompatible.
# graphrag 2.1.0 requires tiktoken<0.9.0,>=0.8.0, but you have tiktoken 0.9.0 which is incompatible.
# graphrag 2.1.0 requires tqdm<5.0.0,>=4.67.1, but you have tqdm 4.66.1 which is incompatible.
# langchain-ollama 0.3.0 requires ollama<1,>=0.4.4, but you have ollama 0.3.3 which is incompatible.
# zenml 0.74.0 requires click<8.1.4,>=8.0.1, but you have click 8.1.7 which is incompatible.
# zenml 0.74.0 requires cloudpickle<3,>=2.0.0, but you have cloudpickle 3.1.1 which is incompatible.
# zenml 0.74.0 requires pydantic<2.9,>=2.8, but you have pydantic 2.11.3 which is incompatible.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# zenml 0.74.0 requires click<8.1.4,>=8.0.1, but you have click 8.1.7 which is incompatible.
# zenml 0.74.0 requires cloudpickle<3,>=2.0.0, but you have cloudpickle 3.1.1 which is incompatible.
# zenml 0.74.0 requires pydantic<2.9,>=2.8, but you have pydantic 2.11.3 which is incompatible.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 28
#      26 from langchain_core.output_parsers import StrOutputParser
#      27 from langchain_core.runnables import RunnablePassthrough
# ---> 28 from langchain_openai import ChatOpenAI, OpenAIEmbeddings
#      31 # Load Documents
#      32 loader = WebBaseLoader(
#      33     web_paths=("https://lilianweng.github.io/posts/2023-06-23-agent/",),
#      34     bs_kwargs=dict(
#    (...)
#      38     ),
#      39 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_openai\__init__.py:1
# ----> 1 from langchain_openai.chat_models import AzureChatOpenAI, ChatOpenAI
#       2 from langchain_openai.embeddings import AzureOpenAIEmbeddings, OpenAIEmbeddings
#       3 from langchain_openai.llms import AzureOpenAI, OpenAI
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_openai\chat_models\__init__.py:1
# ----> 1 from langchain_openai.chat_models.azure import AzureChatOpenAI
#       2 from langchain_openai.chat_models.base import ChatOpenAI
#       4 __all__ = ["ChatOpenAI", "AzureChatOpenAI"]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_openai\chat_models\azure.py:21
#      18 from pydantic import BaseModel, Field, SecretStr, model_validator
#      19 from typing_extensions import Literal, Self
# ---> 21 from langchain_openai.chat_models.base import BaseChatOpenAI
#      23 logger = logging.getLogger(__name__)
#      26 _BM = TypeVar("_BM", bound=BaseModel)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_openai\chat_models\base.py:47
#      40 from langchain_core.language_models import LanguageModelInput
#      41 from langchain_core.language_models.chat_models import (
#      42     BaseChatModel,
#      43     LangSmithParams,
#      44     agenerate_from_stream,
#      45     generate_from_stream,
#      46 )
# ---> 47 from langchain_core.messages import (
#      48     AIMessage,
#      49     AIMessageChunk,
#      50     BaseMessage,
#      51     BaseMessageChunk,
#      52     ChatMessage,
#      53     ChatMessageChunk,
#      54     FunctionMessage,
#      55     FunctionMessageChunk,
#      56     HumanMessage,
#      57     HumanMessageChunk,
#      58     InvalidToolCall,
#      59     SystemMessage,
#      60     SystemMessageChunk,
#      61     ToolCall,
#      62     ToolMessage,
#      63     ToolMessageChunk,
#      64     convert_to_openai_image_block,
#      65     is_data_content_block,
#      66 )
#      67 from langchain_core.messages.ai import (
#      68     InputTokenDetails,
#      69     OutputTokenDetails,
#      70     UsageMetadata,
#      71 )
#      72 from langchain_core.messages.tool import tool_call_chunk
#
# ImportError: cannot import name 'convert_to_openai_image_block' from 'langchain_core.messages' (C:\Users\ashwinir\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\messages\__init__.py)

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

# Prompt Template
template = """Answer the question based only on the following context:
{context}

Question: {question}
"""
prompt = ChatPromptTemplate.from_template(template)

# LLM
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

# RAG Chain
rag_chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# Final Question
output = rag_chain.invoke("What is Task Decomposition?")
print(output)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 4
#       2 from langchain_core.runnables import RunnablePassthrough
#       3 from langchain.prompts import ChatPromptTemplate
# ----> 4 from langchain_openai import ChatOpenAI
#       6 # Prompt Template
#       7 template = """Answer the question based only on the following context:
#       8 {context}
#       9
#      10 Question: {question}
#      11 """
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_openai\__init__.py:1
# ----> 1 from langchain_openai.chat_models import AzureChatOpenAI, ChatOpenAI
#       2 from langchain_openai.embeddings import AzureOpenAIEmbeddings, OpenAIEmbeddings
#       3 from langchain_openai.llms import AzureOpenAI, OpenAI
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_openai\chat_models\__init__.py:1
# ----> 1 from langchain_openai.chat_models.azure import AzureChatOpenAI
#       2 from langchain_openai.chat_models.base import ChatOpenAI
#       4 __all__ = ["ChatOpenAI", "AzureChatOpenAI"]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_openai\chat_models\azure.py:21
#      18 from pydantic import BaseModel, Field, SecretStr, model_validator
#      19 from typing_extensions import Literal, Self
# ---> 21 from langchain_openai.chat_models.base import BaseChatOpenAI
#      23 logger = logging.getLogger(__name__)
#      26 _BM = TypeVar("_BM", bound=BaseModel)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_openai\chat_models\base.py:47
#      40 from langchain_core.language_models import LanguageModelInput
#      41 from langchain_core.language_models.chat_models import (
#      42     BaseChatModel,
#      43     LangSmithParams,
#      44     agenerate_from_stream,
#      45     generate_from_stream,
#      46 )
# ---> 47 from langchain_core.messages import (
#      48     AIMessage,
#      49     AIMessageChunk,
#      50     BaseMessage,
#      51     BaseMessageChunk,
#      52     ChatMessage,
#      53     ChatMessageChunk,
#      54     FunctionMessage,
#      55     FunctionMessageChunk,
#      56     HumanMessage,
#      57     HumanMessageChunk,
#      58     InvalidToolCall,
#      59     SystemMessage,
#      60     SystemMessageChunk,
#      61     ToolCall,
#      62     ToolMessage,
#      63     ToolMessageChunk,
#      64     convert_to_openai_image_block,
#      65     is_data_content_block,
#      66 )
#      67 from langchain_core.messages.ai import (
#      68     InputTokenDetails,
#      69     OutputTokenDetails,
#      70     UsageMetadata,
#      71 )
#      72 from langchain_core.messages.tool import tool_call_chunk
#
# ImportError: cannot import name 'convert_to_openai_image_block' from 'langchain_core.messages' (C:\Users\ashwinir\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\messages\__init__.py)
