# %%
import os
print(os.getcwd())
# Out:
# C:\Users\ashwinir\OneDrive - Jafferjee Brothers\Desktop\newGit\AIOps-Framework\Research_Manith\Advance

# %%
# !Data_Extraction\env\Scripts\activate

# %%
# !pip list
# Out:
# Package                                  Version         Editable project location
# ---------------------------------------- --------------- -------------------------------------------------------------------
# accelerate                               1.5.2
# aiofiles                                 24.1.0
# aiohappyeyeballs                         2.4.6
# aiohttp                                  3.11.12
# aiolimiter                               1.2.1
# aiosignal                                1.3.2
# alabaster                                1.0.0
# alembic                                  1.8.1
# altair                                   5.5.0
# amazon-transcribe                        0.6.2
# annotated-types                          0.7.0
# anthropic                                0.49.0
# antlr4-python3-runtime                   4.9.3
# anyio                                    4.8.0
# anytree                                  2.12.1
# argcomplete                              3.6.0
# argon2-cffi                              23.1.0
# argon2-cffi-bindings                     21.2.0
# arrow                                    1.3.0
# asgiref                                  3.8.1
# assemblyai                               0.36.0
# asttokens                                2.4.1
# async-lru                                2.0.4
# attrs                                    25.1.0
# autograd                                 1.7.0
# awscrt                                   0.16.26
# azure-common                             1.1.28
# azure-core                               1.32.0
# azure-cosmos                             4.9.0
# azure-identity                           1.21.0
# azure-search-documents                   11.5.2
# azure-storage-blob                       12.25.1
# babel                                    2.16.0
# backoff                                  2.2.1
# bcrypt                                   4.0.1
# beartype                                 0.18.5
# beautifulsoup4                           4.12.3
# black                                    24.3.0
# bleach                                   6.2.0
# blinker                                  1.9.0
# blis                                     1.2.0
# boto3                                    1.36.6
# botocore                                 1.36.6
# braceexpand                              0.1.7
# build                                    1.2.2.post1
# cachetools                               5.5.0
# catalogue                                2.0.10
# certifi                                  2024.12.14
# cffi                                     1.17.1
# cfgv                                     3.4.0
# chardet                                  5.2.0
# charset-normalizer                       3.4.1
# chroma-hnswlib                           0.7.6
# chromadb                                 1.0.0
# click                                    8.1.3
# cloudpathlib                             0.21.0
# cloudpickle                              2.2.1
# cohere                                   5.14.0
# colorama                                 0.4.6
# coloredlogs                              15.0.1
# comm                                     0.2.2
# confection                               0.1.5
# contourpy                                1.3.1
# cryptography                             44.0.1
# cycler                                   0.12.1
# cymem                                    2.0.11
# dataclasses-json                         0.6.7
# debugpy                                  1.8.12
# decorator                                5.1.1
# defusedxml                               0.7.1
# Deprecated                               1.2.18
# deprecation                              2.1.0
# devtools                                 0.12.2
# diffusers                                0.32.2
# diskcache                                5.6.3
# distlib                                  0.3.9
# distro                                   1.9.0
# docker                                   7.1.0
# docstring_parser_fork                    0.0.12
# docutils                                 0.21.2
# durationpy                               0.9
# effdet                                   0.4.1
# einops                                   0.8.0
# elevenlabs                               1.50.5
# emoji                                    2.14.1
# encodec                                  0.1.1
# environs                                 11.2.1
# et_xmlfile                               2.0.0
# eval_type_backport                       0.2.2
# executing                                2.2.0
# fastapi                                  0.115.9
# fastavro                                 1.10.0
# fastcore                                 1.7.28
# fastjsonschema                           2.21.1
# fastprogress                             1.0.3
# ffmpy                                    0.5.0
# filelock                                 3.16.1
# filetype                                 1.2.0
# flake8                                   7.0.0
# Flask                                    3.1.0
# flatbuffers                              25.2.10
# fnllm                                    0.2.8
# fonttools                                4.55.0
# fqdn                                     1.5.1
# frozenlist                               1.5.0
# fsspec                                   2024.10.0
# future                                   1.0.0
# gensim                                   4.3.3
# ghp-import                               2.1.0
# gitdb                                    4.0.12
# GitPython                                3.1.44
# google-ai-generativelanguage             0.6.15
# google-api-core                          2.24.0
# google-api-python-client                 2.166.0
# google-auth                              2.37.0
# google-auth-httplib2                     0.2.0
# google-cloud-speech                      2.30.0
# google-cloud-texttospeech                2.24.0
# google-cloud-vision                      3.10.1
# google-genai                             0.3.0
# google-generativeai                      0.8.4
# googleapis-common-protos                 1.66.0
# gradio                                   5.23.1
# gradio_client                            1.8.0
# graphrag                                 2.1.0
# graspologic                              3.4.1
# graspologic-native                       1.2.3
# greenlet                                 3.1.1
# griffe                                   1.6.1
# groovy                                   0.1.2
# groq                                     0.20.0
# grpcio                                   1.69.0
# grpcio-status                            1.69.0
# gym                                      0.26.2
# gym-notices                              0.0.8
# h11                                      0.14.0
# html5lib                                 1.1
# httpcore                                 1.0.7
# httplib2                                 0.22.0
# httptools                                0.6.4
# httpx                                    0.28.1
# httpx-sse                                0.4.0
# huggingface-hub                          0.29.3
# humanfriendly                            10.0
# HyperPyYAML                              1.2.2
# hyppo                                    0.4.0
# identify                                 2.6.6
# idna                                     3.10
# imagesize                                1.4.1
# importlib_metadata                       8.5.0
# importlib_resources                      6.5.2
# iniconfig                                2.0.0
# inquirerpy                               0.3.4
# ipinfo                                   5.1.1
# ipykernel                                6.29.5
# ipython                                  8.31.0
# ipywidgets                               8.1.5
# isodate                                  0.7.2
# isoduration                              20.11.0
# isort                                    5.13.2
# itsdangerous                             2.2.0
# jedi                                     0.19.2
# Jinja2                                   3.1.4
# jiter                                    0.8.2
# jmespath                                 1.0.1
# joblib                                   1.4.2
# json_repair                              0.40.0
# json5                                    0.10.0
# jsonpatch                                1.33
# jsonpath-python                          1.0.6
# jsonpointer                              3.0.0
# jsonschema                               4.23.0
# jsonschema-specifications                2024.10.1
# jupyter                                  1.1.1
# jupyter_client                           8.6.3
# jupyter-console                          6.6.3
# jupyter_core                             5.7.2
# jupyter-events                           0.11.0
# jupyter-lsp                              2.2.5
# jupyter_server                           2.15.0
# jupyter_server_terminals                 0.5.3
# jupyterlab                               4.3.5
# jupyterlab_pygments                      0.3.0
# jupyterlab_server                        2.27.3
# jupyterlab_widgets                       3.0.13
# kiwisolver                               1.4.7
# kubernetes                               32.0.1
# lancedb                                  0.17.0
# langchain                                0.3.21
# langchain-community                      0.3.20
# langchain-core                           0.3.49
# langchain-experimental                   0.3.4
# langchain-ollama                         0.3.0
# langchain-openai                         0.3.11
# langchain-text-splitters                 0.3.7
# langchainhub                             0.1.21
# langcodes                                3.5.0
# langdetect                               1.0.9
# langsmith                                0.3.8
# language_data                            1.3.0
# libretranslatepy                         2.1.1
# llama_cpp_python                         0.3.7
# llvmlite                                 0.44.0
# logfire-api                              3.9.0
# ltx-video                                0.1.2           C:\Users\ashwinir\OneDrive - Jafferjee Brothers\Desktop\j\LTX-Video
# lxml                                     5.3.1
# Mako                                     1.3.9
# marisa-trie                              1.2.1
# Markdown                                 3.7
# markdown-it-py                           3.0.0
# MarkupSafe                               3.0.2
# marshmallow                              3.26.1
# matplotlib                               3.9.2
# matplotlib-inline                        0.1.7
# mccabe                                   0.7.0
# mdurl                                    0.1.2
# mergedeep                                1.3.4
# mistralai                                1.5.1
# mistune                                  3.1.1
# mkdocs                                   1.6.1
# mkdocs-get-deps                          0.2.0
# mmh3                                     5.1.0
# monotonic                                1.6
# more-itertools                           10.6.0
# mpmath                                   1.3.0
# msal                                     1.32.0
# msal-extensions                          1.3.1
# multidict                                6.1.0
# murmurhash                               1.0.12
# mypy-extensions                          1.0.0
# mysql                                    0.0.3
# mysql-connector-python                   9.2.0
# mysqlclient                              2.2.7
# narwhals                                 1.33.0
# nbclient                                 0.10.2
# nbconvert                                7.16.6
# nbformat                                 5.10.4
# neo4j                                    5.28.1
# neo4j-driver                             5.28.1
# nest-asyncio                             1.6.0
# networkx                                 3.4.2
# nltk                                     3.9.1
# nodeenv                                  1.9.1
# notebook                                 7.3.2
# notebook_shim                            0.2.4
# numba                                    0.61.0
# numpy                                    1.26.4
# oauthlib                                 3.2.2
# olefile                                  0.47
# ollama                                   0.4.7
# omegaconf                                2.3.0
# onnx                                     1.17.0
# onnxruntime                              1.20.1
# openai                                   1.69.0
# openai-whisper                           20240930
# opencv-python                            4.11.0.86
# openpyxl                                 3.1.5
# opentelemetry-api                        1.30.0
# opentelemetry-exporter-otlp-proto-common 1.30.0
# opentelemetry-exporter-otlp-proto-grpc   1.30.0
# opentelemetry-instrumentation            0.51b0
# opentelemetry-instrumentation-asgi       0.51b0
# opentelemetry-instrumentation-fastapi    0.51b0
# opentelemetry-proto                      1.30.0
# opentelemetry-sdk                        1.30.0
# opentelemetry-semantic-conventions       0.51b0
# opentelemetry-util-http                  0.51b0
# orjson                                   3.10.15
# overrides                                7.7.0
# packaging                                24.2
# pandas                                   2.2.3
# pandocfilters                            1.5.1
# parso                                    0.8.4
# passlib                                  1.7.4
# pathspec                                 0.12.1
# patsy                                    1.0.1
# pdf2image                                1.17.0
# pdfminer.six                             20250327
# pfzy                                     0.3.4
# phonenumbers                             8.13.53
# pi_heif                                  0.22.0
# pickleshare                              0.7.5
# pikepdf                                  9.5.2
# pillow                                   11.1.0
# pip                                      25.0.1
# platformdirs                             4.3.6
# pluggy                                   1.5.0
# posthog                                  3.18.0
# POT                                      0.9.5
# pre_commit                               4.1.0
# preshed                                  3.0.9
# prometheus_client                        0.21.1
# prompt_toolkit                           3.0.50
# propcache                                0.2.1
# proto-plus                               1.25.0
# protobuf                                 5.29.3
# psutil                                   6.1.1
# pure_eval                                0.2.3
# py-cpuinfo                               9.0.0
# pyarrow                                  15.0.2
# pyasn1                                   0.6.1
# pyasn1_modules                           0.4.1
# PyAudio                                  0.2.14
# pycocotools                              2.0.8
# pycodestyle                              2.11.0
# pycparser                                2.22
# pydantic                                 2.10.6
# pydantic-ai                              0.0.41
# pydantic-ai-slim                         0.0.41
# pydantic_core                            2.27.2
# pydantic-graph                           0.0.41
# pydantic-settings                        2.7.1
# pydeck                                   0.9.1
# pydoclint                                0.4.1
# pydub                                    0.25.1
# pyflakes                                 3.2.0
# Pygments                                 2.19.1
# pygtrie                                  2.5.0
# PyJWT                                    2.7.0
# pylance                                  0.20.0
# PyMySQL                                  1.1.1
# pynndescent                              0.5.13
# pypandoc                                 1.15
# pyparsing                                3.2.0
# pypdf                                    5.3.1
# PyPDF2                                   3.0.1
# pypdfium2                                4.30.1
# PyPika                                   0.48.9
# pyproject_hooks                          1.2.0
# pyreadline3                              3.5.4
# pytest                                   7.4.0
# python-dateutil                          2.9.0.post0
# python-docx                              1.1.2
# python-dotenv                            1.1.0
# python-iso639                            2025.2.18
# python-json-logger                       3.2.1
# python-magic                             0.4.27
# python-multipart                         0.0.20
# python-oxmsg                             0.0.2
# python-pptx                              1.0.2
# pytz                                     2024.2
# pywin32                                  308
# pywinpty                                 2.0.14
# PyYAML                                   6.0.2
# pyyaml_env_tag                           0.1
# pyzmq                                    26.2.0
# RapidFuzz                                3.13.0
# referencing                              0.36.2
# regex                                    2024.11.6
# requests                                 2.32.3
# requests-file                            2.1.0
# requests-oauthlib                        2.0.0
# requests-toolbelt                        1.0.0
# rfc3339-validator                        0.1.4
# rfc3986-validator                        0.1.1
# rich                                     13.9.4
# rpds-py                                  0.22.3
# rsa                                      4.9
# ruamel.yaml                              0.18.10
# ruamel.yaml.clib                         0.2.12
# ruff                                     0.11.2
# s3transfer                               0.11.2
# safehttpx                                0.1.6
# safetensors                              0.5.2
# scikit-learn                             1.6.1
# scipy                                    1.12.0
# seaborn                                  0.13.2
# secure                                   0.3.0
# semantic-version                         2.10.0
# Send2Trash                               1.8.3
# sentence-transformers                    3.4.1
# sentencepiece                            0.2.0
# setuptools                               75.5.0
# shellingham                              1.5.4
# six                                      1.16.0
# smart-open                               7.1.0
# smmap                                    5.0.2
# sniffio                                  1.3.1
# snowballstemmer                          2.2.0
# soundfile                                0.13.1
# soupsieve                                2.6
# spacy                                    3.8.4
# spacy-legacy                             3.0.12
# spacy-loggers                            1.0.5
# speechbrain                              0.5.16
# SpeechRecognition                        3.14.1
# Sphinx                                   8.1.3
# sphinx-rtd-theme                         3.0.2
# sphinxcontrib-applehelp                  2.0.0
# sphinxcontrib-devhelp                    2.0.0
# sphinxcontrib-htmlhelp                   2.1.0
# sphinxcontrib-jquery                     4.1
# sphinxcontrib-jsmath                     1.0.1
# sphinxcontrib-qthelp                     2.0.0
# sphinxcontrib-serializinghtml            2.0.0
# SQLAlchemy                               2.0.38
# SQLAlchemy-Utils                         0.41.2
# sqlmodel                                 0.0.18
# srsly                                    2.5.1
# stack-data                               0.6.3
# starlette                                0.45.3
# statsmodels                              0.14.4
# streamlit                                1.44.1
# sympy                                    1.13.1
# tenacity                                 9.0.0
# terminado                                0.18.1
# textblob                                 0.18.0.post0
# thinc                                    8.3.4
# threadpoolctl                            3.5.0
# tiktoken                                 0.9.0
# timm                                     1.0.15
# tinycss2                                 1.4.0
# tldextract                               5.1.3
# tokenizers                               0.21.0
# toml                                     0.10.2
# tomlkit                                  0.13.2
# torch                                    2.6.0
# torchaudio                               2.5.1
# torchvision                              0.21.0
# tornado                                  6.4.2
# tqdm                                     4.67.1
# traitlets                                5.14.3
# transformers                             4.48.1
# translate                                3.6.1
# typer                                    0.15.2
# types-python-dateutil                    2.9.0.20241206
# types-requests                           2.32.0.20241016
# typing_extensions                        4.12.2
# typing-inspect                           0.9.0
# typing-inspection                        0.4.0
# tzdata                                   2025.1
# ultralytics                              8.3.91
# ultralytics-thop                         2.0.14
# umap-learn                               0.5.7
# unstructured                             0.17.2
# unstructured-client                      0.32.1
# unstructured-inference                   0.8.10
# unstructured.pytesseract                 0.3.15
# uri-template                             1.3.0
# uritemplate                              4.1.1
# urllib3                                  2.3.0
# uvicorn                                  0.34.0
# virtualenv                               20.29.1
# vocos                                    0.1.0
# wasabi                                   1.1.3
# watchdog                                 6.0.0
# watchfiles                               1.0.4
# wcwidth                                  0.2.13
# weasel                                   0.4.1
# webcolors                                24.11.1
# webdataset                               0.2.100
# webencodings                             0.5.1
# websocket-client                         1.8.0
# websockets                               14.1
# Werkzeug                                 3.1.3
# whisper                                  1.1.10
# WhisperSpeech                            0.8.9
# widgetsnbextension                       4.0.13
# wrapt                                    1.17.2
# xlrd                                     2.0.1
# XlsxWriter                               3.2.2
# yamllint                                 1.35.1
# yarl                                     1.18.3
# yfiles_jupyter_graphs                    1.10.1
# zenml                                    0.74.0
# zipp                                     3.21.0
# zstandard                                0.23.0

# %%
# %pip install -q "unstructured[all-docs]" pillow lxml pillow
# %pip install -q chromadb tiktoken
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
from unstructured.partition.pdf import partition_pdf

file_path = "2023.pdf"

chunks = partition_pdf(
    filename=file_path,
    infer_table_structure=True,            # extract tables
    strategy="hi_res",                     # mandatory to infer tables

    extract_image_block_types=["Image"],   # Add 'Table' to list to extract image of tables
    # image_output_dir_path=output_path,   # if None, images and tables will saved in base64

    extract_image_block_to_payload=True,   # if true, will extract base64 for API usage

    chunking_strategy="by_title",          # or 'basic'
    max_characters=10000,                  # defaults to 500
    combine_text_under_n_chars=2000,       # defaults to 0
    new_after_n_chars=6000,

    # extract_images_in_pdf=True,          # deprecated
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from unstructured.partition.pdf import partition_pdf
#       3 file_path = "2023.pdf"
#       5 chunks = partition_pdf(
#       6     filename=file_path,
#       7     infer_table_structure=True,            # extract tables
#    (...)
#      20     # extract_images_in_pdf=True,          # deprecated
#      21 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\unstructured\partition\pdf.py:19
#      17 from PIL import Image as PILImage
#      18 from pypdf import PdfReader
# ---> 19 from unstructured_inference.inference.layout import DocumentLayout
#      20 from unstructured_inference.inference.layoutelement import LayoutElement
#      22 from unstructured.chunking import add_chunking_strategy
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\unstructured_inference\inference\layout.py:18
#      16 from unstructured_inference.inference.layoutelement import LayoutElement, LayoutElements
#      17 from unstructured_inference.logger import logger
# ---> 18 from unstructured_inference.models.base import get_model
#      19 from unstructured_inference.models.unstructuredmodel import (
#      20     UnstructuredElementExtractionModel,
#      21     UnstructuredObjectDetectionModel,
#      22 )
#      23 from unstructured_inference.visualize import draw_bbox
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\unstructured_inference\models\base.py:7
#       4 import os
#       5 from typing import Dict, Optional, Tuple, Type
# ----> 7 from unstructured_inference.models.detectron2onnx import (
#       8     MODEL_TYPES as DETECTRON2_ONNX_MODEL_TYPES,
#       9 )
#      10 from unstructured_inference.models.detectron2onnx import UnstructuredDetectronONNXModel
#      11 from unstructured_inference.models.unstructuredmodel import UnstructuredModel
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\unstructured_inference\models\detectron2onnx.py:9
#       7 from huggingface_hub.constants import HUGGINGFACE_HUB_CACHE
#       8 from onnxruntime.capi import _pybind_state as C
# ----> 9 from onnxruntime.quantization import QuantType, quantize_dynamic
#      10 from PIL import Image
#      12 from unstructured_inference.constants import Source
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\onnxruntime\quantization\__init__.py:1
# ----> 1 from .calibrate import (  # noqa: F401
#       2     CalibraterBase,
#       3     CalibrationDataReader,
#       4     CalibrationMethod,
#       5     MinMaxCalibrater,
#       6     create_calibrator,
#       7 )
#       8 from .qdq_quantizer import QDQQuantizer  # noqa: F401
#       9 from .quant_utils import QuantFormat, QuantType, write_calibration_table  # noqa: F401
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\onnxruntime\quantization\calibrate.py:17
#      14 from typing import Dict, Optional, Sequence, Tuple, Union
#      16 import numpy as np
# ---> 17 import onnx
#      18 from onnx import ModelProto, TensorProto, helper, numpy_helper
#      20 import onnxruntime
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\onnx\__init__.py:77
#      73 from typing import IO, Literal, Union
#      76 from onnx import serialization
# ---> 77 from onnx.onnx_cpp2py_export import ONNX_ML
#      78 from onnx.external_data_helper import (
#      79     load_external_data_for_model,
#      80     write_external_data_tensors,
#      81     convert_model_to_external_data,
#      82 )
#      83 from onnx.onnx_pb import (
#      84     AttributeProto,
#      85     EXPERIMENTAL,
#    (...)
#     111     Version,
#     112 )
#
# ImportError: DLL load failed while importing onnx_cpp2py_export: A dynamic link library (DLL) initialization routine failed.

# %%
import base64
from IPython.display import Image, display

def display_base64_image(base64_code):
    # Decode the base64 string to binary
    image_data = base64.b64decode(base64_code)
    # Display the image
    display(Image(data=image_data))

display_base64_image(images[0])
